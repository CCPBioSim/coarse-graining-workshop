# %% [markdown]
# ### Assignment 2: Simulating an all atom system

# %% [markdown]
# In this part of the session we will be visualising an all atom simulation of the protein YidC in a phospholipid bilayer. \
# Running such simulations takes more computational resource than we have available in this practical, and so \
# we have provided the files for you already in this (2-allatom_sim) directory.

# %%
# %%bash
#
# ls

# %% [markdown]
# In the above output, we should see a few different files, with various file types. \
# These are the standard GROMACS simulation files that may already be familiar to you\
# along with a directory "mdp-files" containing typical mdp parameters for an all-atom simulation\
# and a run script that performs the production MD phase from the final file generated by the \
# CHARMM-GUI equilibration protocol.
#
# This simulation was run at all-atom resolution, for 100 ns.\
# We used 24 CPU cores (AMD Ryzen Threadripper 7960X 24-Cores) and 1 GPU (NVIDIA GeForce RTX 5080)\
# It took 10h37:56 to run, equivalent to 225.729 ns/day.\
# You can find all of this data in "production.log"

# %% [markdown]
# Let's visualise the simulation. In a separate terminal (NOT in this notebook), run the following command:

# %%
# %%bash
#
# vmd production_formatted.gro production_formatted.xtc

# %% [markdown]
# Open the Representations pane via "Graphics > Representations.."
#
# Set up the representations to match the following:
#
# <img src="images/vmdRepresentation.png" width="350">

# %% [markdown]
# Question a) What atoms of what molecules does the selection "name P P1 P3" represent?
#
# Question b) Consider your answers to the questions in the previous assignment, do you see anything in this simulation that might support these thoughts/observations?
#
# Question c) If so why? / If not why not?

# %% [markdown]
# In your own time, you can run the production MD simulation via the following commands:

# %%
chmod u+x run

./run
